# %% [markdown]
# <a href="https://colab.research.google.com/github/dngtundt/THDL_DangAnhTuan/blob/main/THDL_Buoi3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# BUỔI 3 - ANN -
# BÀI THỰC HÀNH 3: ARTIFICIAL NEURAL NETWORK

# %% [markdown]
# REGRESSION MODEL
